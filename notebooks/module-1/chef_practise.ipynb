# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver  

agent = create_agent(
    model="deepseek-chat",
    checkpointer=InMemorySaver(),
    system_prompt=system_prompt,
    tools=[web_search]
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="I have some leftover paneer and rice. What can I make?")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

print(response['messages'][-1].content)
# Out:
# I found even more great options for you! Here are the best recipes you can make with your leftover **paneer and rice**:
#
# ---
#
# ## 🍽️ Recipe Suggestions
#
# ### 1. **Paneer Fried Rice** ⭐ *My top pick*
# The classic and easiest option. Great for leftover rice!
# - **Indian style**: Sauté garlic, ginger, onions, and green chilies with veggies, add marinated paneer cubes, then toss in rice with spices.
# - **Chinese style**: Add soy sauce, vinegar, chili sauce, and black pepper for an Indo-Chinese kick.
#
# ---
#
# ### 2. **Paneer Bhurji Rice / Pulao**
# Crumble the paneer and sauté it with onion, tomato, ginger-garlic paste, and spices (turmeric, red chili, garam masala) to make a spiced **paneer bhurji (scrambled paneer)**, then mix it with your leftover rice. Quick, flavorful, and comforting!
#
# ---
#
# ### 3. **10-Minute Paneer Masala Pulao**
# Specifically designed for leftover rice:
# - Heat oil + butter, add mustard seeds, cumin, curry leaves, and green chilies
# - Sauté paneer cubes with all the spices
# - Toss in leftover rice and cook for a few minutes
# - Perfect for a quick lunch or dinner!
#
# ---
#
# ### 4. **Paneer Pulao**
# A more elaborate one-pot dish with whole spices (bay leaf, cinnamon, cloves, cardamom), sautéed onions, veggies, mint, and coriander. Fold in fried paneer cubes at the end.
#
# ---
#
# ### 5. **Paneer Tikka Rice Bowl**
# Marinate paneer in yogurt and spices, grill or pan-fry until charred, and serve over rice with fresh salad, lemon, and a yogurt drizzle. Modern and healthy!
#
# ---
#
# ### 6. **Beetroot Paneer Rice**
# A colorful twist — sauté grated beetroot with spices and paneer, then toss with leftover rice. Mild, slightly sweet, and great for lunchboxes.
#
# ---
#
# ### 7. **Green Paneer Pulao**
# Blend fresh greens (spinach, mint, coriander) into a paste, use it to flavor your rice, and mix in paneer cubes. Fresh, healthy, and vibrant!
#
# ---
#
# ## 🌟 Which one sounds best to you?
# If you want, I can give you the **detailed step-by-step recipe** for any of these. Just let me know which one you'd like to make, and also if there are any other ingredients you have on hand (onions, tomatoes, sauces, etc.) so I can tailor the recipe to your kitchen! 😊

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover paneer and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='803db585-33f8-43db-8bfb-7e8411c06afe'),
#               AIMessage(content='Let me search for some delicious recipes you can make with paneer and rice as your main ingredients!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 107, 'prompt_tokens': 345, 'total_tokens': 452, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 345}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '2ca8285a-e3dc-45a6-8a83-47535d913cd6', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0110e-279f-7552-8ea4-90437554c082-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'easy recipes with leftover paneer and rice'}, 'id': 'call_00_SzBjCzQkp7KBqkI6aiPr2202', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'paneer rice recipes quick and easy'}, 'id': 'call_01_WUtmq9LHPOdM88VLjxX09455', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 345, 'output_tokens': 107, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}),
#               ToolMessage(content='{"query": "easy recipes with leftover paneer and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=IYJkWxwlmIE&vl=en-US", "title": "10-Minute Paneer Pulao Recipe | Leftover rice tiffin recipe | Easy paneer pulao dinner idea | Nirav", "content": "Transform your leftover rice into a mouthwatering Paneer Masala Pulao in just 10 minutes! This quick, flavorful recipe is perfect for tiffin boxes or a simple dinner. Spiced perfectly with tender paneer and aromatic herbs, it’s the perfect way to avoid food waste while enjoying a hearty, satisfying meal. Easy to make, delicious to eat!\\"\\n\\nSearchable Keywords: [...] बचे चावल से सिर्फ 10 मिनट में बनाए मजेदार और चटपटा पनीर मसाला राइस टिफिन के लिए परफेक्ट और रात के खाने में सबका दिल जीतने वाला और साथ में ठंडी दही मिल जाए ओए होय होए इसका स्वाद और भी लाजवाब हो जाता है सबसे पहले कढ़ाई में डालेंगे 2 टेबलस्पून तेल तेल को मध्यम आंच पे गरम करें फिर इसमें हम डालेंगे 30 ग्रा बटर जैसे ही बटर मेल्ट हो जाए डालेंगे 1 टीस्पून राई जैसे ही राई में से फूटने की आवाज आनी शुरू हो जाए डालेंगे 1 टीस्पून जीरा एक या दो मीडियम साइज की कटी हुई हरी मिर्च 12 से 15 कड़ी पत्ता दो छोटी [...] से टुकड़ों में काट ले फिर आधी छोटी चम्मच कश्मीरी लाल मिर्च पाउडर आधी छोटी चम्मच धनिया पाउडर धनिया जीरा पाउडर ना डाले आधी छोटी चम्मच हल्दी पाउडर एक टीस्पून पांव भाजी मसाला इसे जरूर से डालिए आधी छोटी चम्मच गरम मसाला अब यहां पे डाली हुई सभी चीजों को अच्छे से मिक्स कर ले और इस तरह से चलाते हुए दो से 3 मिनट तक पनीर को पका लें जब मसाले पनीर के साथ अच्छे से मिक्स हो जाए थोड़ा पनीर को भून लेने के बाद इसमें हम डालेंगे लेफ्ट ओवर राइस ये मैं चार कटोरी उबले हुए चावल डाल रहा हूं और और इसी के साथ डालेंगे नमक", "score": 0.890761, "raw_content": null, "id": "12dd62-00"}, {"url": "https://www.sharmispassions.com/paneer-pulao-recipe", "title": "Paneer Pulao Recipe | Paneer Rice Recipe - Sharmis Passions", "content": "Add ¼ cup carrot, ⅓ cup green peas along with ¼ cup mint, coriander leaves.\\n Saute well for 2 minutes.\\n Add drained basmati rice and give a quick mix.\\n Add 2 cups water. Check and adjust salt at this stage. The water should be salty only then when rice is cooked salt will be apt.\\n Pressure cook for 2 whistles in medium flame. Switch off.\\n Add fried paneer cubes.\\n Mix it well and your paneer pulao is ready to serve!\\n Serve it with plain curd or onion raita. [...] 12.Saute well for 2 minutes.\\n\\n13.Add drained basmati rice and give a quick mix.\\n\\n14.Add 2 cups water. Check and adjust salt at this stage. The water should be salty only then when rice is cooked salt will be apt.\\n\\n15.Pressure cook for 2 whistles in medium flame. Switch off.\\n\\n16.Add fried paneer cubes.\\n\\n17.Mix it well and your paneer pulao is ready to serve!\\n\\nServe it with plain curd or onion raita.\\n\\n## Expert Tips [...] First rinse 1 cup basmati rice in water well at least 2-3 times then soak it in water for 30 minutes.\\n After 30 minutes drain water and set the rice aside.\\n To a bowl add 200 grams paneer along with salt to taste, ½ teaspoon red chili powder and ¼ teaspoon garam masala powder, ½ teaspoon ginger garlic paste.\\n Mix it well until the spices coat well.\\n Meanwhile to a pan add little oil and shallow fry the paneer cubes in batches.", "score": 0.76554126, "raw_content": null, "id": "f9a7ba-01"}, {"url": "https://hebbarskitchen.com/paneer-fried-rice-recipe-paneer-fry-rice", "title": "paneer fried rice recipe | paneer fry rice | veg paneer fried rice", "content": "Anyway, I would like to conclude this post with some tips, suggestions, and variations for a perfect paneer fried rice recipe. Firstly, I would heavily recommend using dry or leftover basmati rice for this recipe. If you plan to use freshly cooked rice, ensure to make it moisture-free by drying it out on a plate. Secondly, with respect to the addition of vegetables, it is completely open-ended. I have added the basic vegetables, but you can easily experime ...
#               ToolMessage(content='{"query": "paneer rice recipes quick and easy", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.sharmispassions.com/paneer-pulao-recipe", "title": "Paneer Pulao Recipe | Paneer Rice Recipe - Sharmis Passions", "content": "12.Saute well for 2 minutes.\\n\\n13.Add drained basmati rice and give a quick mix.\\n\\n14.Add 2 cups water. Check and adjust salt at this stage. The water should be salty only then when rice is cooked salt will be apt.\\n\\n15.Pressure cook for 2 whistles in medium flame. Switch off.\\n\\n16.Add fried paneer cubes.\\n\\n17.Mix it well and your paneer pulao is ready to serve!\\n\\nServe it with plain curd or onion raita.\\n\\n## Expert Tips [...] Add ¼ cup carrot, ⅓ cup green peas along with ¼ cup mint, coriander leaves.\\n Saute well for 2 minutes.\\n Add drained basmati rice and give a quick mix.\\n Add 2 cups water. Check and adjust salt at this stage. The water should be salty only then when rice is cooked salt will be apt.\\n Pressure cook for 2 whistles in medium flame. Switch off.\\n Add fried paneer cubes.\\n Mix it well and your paneer pulao is ready to serve!\\n Serve it with plain curd or onion raita. [...] 3.To a bowl add 200 grams paneer along with salt to taste, ½ teaspoon red chili powder and ¼ teaspoon garam masala powder, ½ teaspoon ginger garlic paste.\\n\\n4.Mix it well until the spices coat well.\\n\\n5.Meanwhile to a pan add little oil and shallow fry the paneer cubes in batches.\\n\\n6.Fry until golden brown. Fry in batches repeat to finish. Remove the paneer cubes and set it aside.", "score": 0.8865877, "raw_content": null, "id": "18b9dc-00"}, {"url": "https://www.indianhealthyrecipes.com/paneer-pulao", "title": "Paneer Pulao Recipe | Paneer Rice - Swasthi\'s Recipes", "content": "3. Saute ginger garlic paste till the raw smell is gone, for 1 minute. Add all the chopped veggies, mint and coriander leaves. Saute for 2 to 3 mins. Pour water and stir in salt. Taste test and adjust salt to make it slightly salty.\\n4. Bring it to a boil. Add soaked and drained rice and pressure cook for 1 whistle on a medium flame. If cooking in a pot, cover and cook on a low flame until the rice is done. [...] 1. Prep-up paneer: Add all the marination ingredients including 1½ tablespoon oil to paneer. Mix and set aside. If it is too dry, sprinkle 1 tbsp water. Rinse and soak rice in water for 15 mins.\\n2. Make pulao rice: Heat oil or ghee in a pot or cooker. Add all the whole spices. When they begin to sizzle, add sliced onions & green chilies. Saute them until golden. [...] More Rice Recipes you may like  \\nTawa pulao  \\nJeera rice  \\nMatar pulao  \\nCarrot pulao\\n\\nIf you love paneer, you may check more Paneer Recipes here.\\n\\nPhoto Guide\\n\\n## Step by Step Photo Instructions\\n\\n1. Rinse 1½ cups aged basmati rice thrice and optionally soak it in water for 15 mins. Meanwhile prep up the rest. Rinse 1½ cups cubed paneer to make it moist or sprinkle 1 tbsp of water. Drain the water completely. Add", "score": 0.85825616, "raw_content": null, "id": "eb8a9d-01"}, {"url": "https://www.indianhealthyrecipes.com/paneer-fried-rice", "title": "Paneer fried rice (Indian & Chinese 2 Ways) - Swasthi\'s Recipes", "content": "1. Heat a pan with 1 tablespoon oil. Add the marinated paneer and fry on a high heat until all of the moisture dries up. Remove to a plate.\\n2. To the same pan, add more oil and hear. Add garlic, chillies and spring onion whites. Saute for 30 seconds.\\n3. Then add mixed vegetables and saute until the veggies are cooked yet remain crunchy.\\n4. Add fried paneer and spring onion greens. Pour soya sauce. [...] 1. Add 1 tbsp olive oil to a pan and fry 2 chopped garlic cloved and 1 strand of mace. Mace imparts a good aroma to the rice and so you can skip using sauce for this recipe.\\n\\n2. Add 3/4 cup chopped veggies and fry until slightly tender yet crunchy. I used carrots, beans , spring onions and capsicums. ...
#               AIMessage(content='Let me search for a couple more specific recipe ideas to give you a good variety of options.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 107, 'prompt_tokens': 4883, 'total_tokens': 4990, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 256}, 'prompt_cache_hit_tokens': 256, 'prompt_cache_miss_tokens': 4627}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '18ce6f71-98dd-4d72-b676-bab3f82a18c7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0110e-3412-7e81-9794-7d216bc10909-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'paneer khichdi recipe leftover rice'}, 'id': 'call_00_8UNxGaXTOYDSDgT5BPcY5678', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'paneer tikka rice bowl recipe easy'}, 'id': 'call_01_3mtKcbSQThxrlSHFbVTY0530', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 4883, 'output_tokens': 107, 'total_tokens': 4990, 'input_token_details': {'cache_read': 256}, 'output_token_details': {}}),
#               ToolMessage(content='{"query": "paneer khichdi recipe leftover rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/chefatlarge/posts/5546236995464897", "title": "Dal khichdi, a flavorful leftover rice and dal makeover - Facebook", "content": "Ingredients : 1 cup leftover MoongDal Khichdi 1/4 cup corn boiled and chrushed 3 tbsp corn Flour 1/4 cup paneer grated 1 potato boiled and", "score": 0.826278, "raw_content": null, "id": "df8d24-00"}, {"url": "https://www.facebook.com/yourfoodlab/posts/if-you-also-have-leftover-rice-at-your-home-i-have-an-amazing-recipe-for-you-the/1472379620906309", "title": "If you also have leftover rice at your home, I have an amazing recipe for ...", "content": "3) PANEER FRIED RICE Ingredients: • 2 cups cooked basmati rice • 200 g paneer cubes • 2 tbsp oil • ½ cup chopped onion • ½ cup chopped capsicum/", "score": 0.798643, "raw_content": null, "id": "2ecbce-01"}, {"url": "https://staging.foodfood.com/public/recipedetails/egg-paneer-khichdi", "title": "Egg & Paneer Khichdi - Food Food", "content": "Key Ingredients: Eggs · Cottage cheese (paneer) · Leftover rice · Leftover dal. Leftover rice and dal put to good use – very", "score": 0.75831425, "raw_content": null, "id": "357289-02"}, {"url": "https://www.instagram.com/reel/CveSBt2qZx8?hl=en", "title": "Dal chawal pancake - you can use this recipe for leftover Khichdi, dalia ...", "content": "INGREDIENTS: 1 cup leftover rice 1/2 cup leftover moong dal 1 cup finely chopped cabbage 1/2 cup finely chopped", "score": 0.75181264, "raw_content": null, "id": "8d90ac-03"}, {"url": "https://www.reddit.com/r/Cheap_Meals/comments/brhw2t/dal_khichdi_recipe_with_paneer_an_indian_rice_dish", "title": "Dal Khichdi Recipe with Paneer (an Indian rice dish) - Reddit", "content": "Khichdi + paneer? I saw such combination first time. It looks tasty though, do you make this variation on your own or dish like this", "score": 0.43597415, "raw_content": null, "id": "b0a7a9-04"}], "response_time": 2.12, "request_id": "0e924b31-9f87-4c2c-a52a-5c777f71358e"}', name='web_search', id='657a515c-c5c5-46d7-9f8b-13d6a95685af', tool_call_id='call_00_8UNxGaXTOYDSDgT5BPcY5678'),
#               ToolMessage(content='{"query": "paneer tikka rice bowl recipe easy", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.honeywhatscooking.com/paneer-tikka-rice-bowl", "title": "Paneer Tikka Rice Bowl (Air Fryer version)", "content": "To Assemble Paneer Tikka Rice Bowl (makes 4 servings) · Add rice to a bowl · Add crisp lettuce, chopped · Add cucumber salad · Add paneer & veggies", "score": 0.8173562, "raw_content": null, "id": "4d26a1-00"}, {"url": "https://www.dillandthyme.com/paneer-tikka-masala-rice", "title": "Paneer Tikka Masala Rice | Dill and Thyme", "content": "For the rice: While this mixture is cooling down, place the same pan on the stove and add a couple of tablespoons of ghee/ oil. Add the sliced onions and let cook for 5 minutes. Add the ginger-garlic paste and cook for another 5 minutes. Now add sliced red bell peppers, paneer, salt and mix well.Cook until the peppers have softened. [...] Raita is typically served with most Indian style rice dishes or anything spicy since the yoghurt in the raita balances the heat in the food. Just add some yoghurt to a bowl. Thin it down by adding water to reach the desired consistency. Add salt, cumin powder and some chili powder(optional). You can also add chopped tomatoes, cucumber and/or onions to this. Topping with chopped cilantro leaves is optional. [...] Heat the kadai or braiser and add some ghee. Once hot, add the onions and let this cook for a few minutes. Add the ginger-garlic paste, mix and again cook for 5-7 minutes.\\n Now add the chopped tomatoes, tomato paste and saute for a minute or so. Add all the powdered spices and the kasuri methi. Season with salt and add a cup of boiling water.", "score": 0.7668008, "raw_content": null, "id": "47a750-01"}, {"url": "https://www.instagram.com/p/DXBZsS-EwkL?__d=", "title": "My fav lunch meal = Paneer Tikka Rice Bowl 🍢 ...", "content": "Quick and tasty Paneer Rice Bowl recipe Perfect high-protein meal for lunch or dinner. Easy to make, healthy, and super delicious!", "score": 0.72019166, "raw_content": null, "id": "48c7ad-02"}], "response_time": 1.94, "request_id": "b3787434-03f9-41cd-b14b-ecf076fe12b4"}', name='web_search', id='8b2ee61d-df3a-43c1-8f4e-699106644849', tool_call_id='call_01_3mtKcbSQThxrlSHFbVTY0530'),
#               AIMessage(content="Great! I found some fantastic recipe options for you. Here are the best recipes you can make with your leftover paneer and rice:\n\n---\n\n## 🍽️ Recipe Suggestions for Paneer + Rice\n\n### 1. **Paneer Fried Rice** (Indian-Chinese style)\nThis is probably the most popular and versatile option for leftover rice. There are two ways you can make this:\n- **Indian style**: Sauté garlic, ginger, green chilies, and onions with veggies, add crumbled/cubed paneer, then toss in your leftover rice with spices.\n- **Chinese style**: Add soy sauce, chili sauce, vinegar, and black pepper for a spicy Indo-Chinese twist.\n\n**Key ingredients you'll likely need:** oil, garlic, ginger, onion, green chilies, soy sauce (for Chinese version), black pepper, salt, and whatever veggies you have on hand (carrots, capsicum, beans, spring onions).\n\n---\n\n### 2. **Paneer Pulao**\nA one-pot aromatic rice dish. Marinate paneer cubes with yogurt, red chili powder, garam masala, and ginger-garlic paste, then shallow fry them. Cook rice with whole spices (cumin, bay leaf, cinnamon, cloves), sautéed onions, veggies, and fresh herbs (mint and coriander). Fold the fried paneer into the cooked rice.\n\n**Best served with:** plain yogurt/raita.\n\n---\n\n### 3. **Paneer Tikka Rice Bowl**\nA modern, healthy take — marinate paneer cubes with yogurt, spices, and grill or air-fry them until charred. Serve over your leftover rice with fresh salad (lettuce, cucumber, onion), and optionally a drizzle of lemon and yogurt-based sauce.\n\n---\n\n### 4. **Paneer Masala Pulao (10-minute version)**\nA super quick option specifically designed for **leftover rice**! In a pan:\n- Heat oil + butter, add mustard seeds and cumin\n- Add green chilies, curry leaves, ginger-garlic paste\n- Sauté paneer cubes with red chili powder, coriander powder, turmeric, garam masala\n- Toss in your leftover rice, mix well, and cook for 2-3 minutes\n\n---\n\n### 5. **Paneer Khichdi Cakes/Tikkis** (Creative option!)\nIf you also have some dal or moong lentils, you can mix leftover rice with mashed dal, grated paneer, and spices, then shallow fry them into crispy patties/tikkis.\n\n---\n\n## 🌟 My Top Recommendation:\n**Paneer Fried Rice** — it's the easiest, fastest, and makes the best use of leftover rice and paneer. Perfect for a weekday lunch or dinner!\n\n---\n\nWould you like me to give you the **detailed step-by-step recipe** for any of these? Just let me know which one sounds best to you! 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 602, 'prompt_tokens': 6312, 'total_tokens': 6914, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 4864}, 'prompt_cache_hit_tokens': 4864, 'prompt_cache_miss_tokens': 1448}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '8472cc04-3d7e-4ecf-a6e7-be5952c20429', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0110e-4630-7983-b743-18d762c0a7c5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6312, 'output_tokens': 602, 'total_tokens': 6914, 'input_token_details': {'cache_read': 4864}, 'output_token_details': {}}),
#               AIMessage(content="I found some great options! Let me know which recipe you'd like the detailed step-by-step instructions for, and I'll walk you through it. \n\nTo recap, here are your best options:\n1. **Paneer Fried Rice** (fastest & easiest, great for leftover rice)\n2. **Paneer Pulao** (one-pot aromatic, more elaborate)\n3. **Paneer Tikka Rice Bowl** (healthy modern twist)\n4. **10-Minute Paneer Masala Pulao** (specifically designed for leftover rice)\n5. **Paneer Khichdi Cakes** (crispy pan-fried patties, if you have dal)\n\nWhich one would you like the full recipe for? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 153, 'prompt_tokens': 6917, 'total_tokens': 7070, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 6912}, 'prompt_cache_hit_tokens': 6912, 'prompt_cache_miss_tokens': 5}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'abb31a9f-6953-4531-bb7d-edf930c537a0', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01116-3947-7a93-aaa9-8c8b2b701118-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6917, 'output_tokens': 153, 'total_tokens': 7070, 'input_token_details': {'cache_read': 6912}, 'output_token_details': {}}),
#               AIMessage(content="I found some great options! Let me know which one you'd like the full recipe for. To summarize:\n\n1. **Paneer Fried Rice** — Fastest and easiest, perfect for leftover rice\n2. **Paneer Pulao** — Aromatic one-pot dish\n3. **Paneer Tikka Rice Bowl** — Healthy modern twist\n4. **10-Minute Paneer Masala Pulao** — Made specifically for leftover rice\n5. **Paneer Khichdi Cakes** — Crispy pan-fried patties (if you also have some dal)\n\nWhich one would you like the detailed step-by-step recipe for? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 137, 'prompt_tokens': 7073, 'total_tokens': 7210, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 7040}, 'prompt_cache_hit_tokens': 7040, 'prompt_cache_miss_tokens': 33}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'd5060705-2910-4f51-99b5-39d51a262817', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0111a-31fe-7fe0-bdf4-a9c8b9535070-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7073, 'output_tokens': 137, 'total_tokens': 7210, 'input_token_details': {'cache_read': 7040}, 'output_token_details': {}}),
#               AIMessage(content="I found some great options! Let me know which one you'd like the full recipe for. To summarize:\n\n1. **Paneer Fried Rice** — Fastest and easiest, perfect for leftover rice\n2. **Paneer Pulao** — Aromatic one-pot dish\n3. **Paneer Tikka Rice Bowl** — Healthy modern twist\n4. **10-Minute Paneer Masala Pulao** — Made specifically for leftover rice\n5. **Paneer Khichdi** — Comforting one-pot meal\n\nWhich one would you like the detailed step-by-step recipe for? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 126, 'prompt_tokens': 7213, 'total_tokens': 7339, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 7168}, 'prompt_cache_hit_tokens': 7168, 'prompt_cache_miss_tokens': 45}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'cbd8dc4d-2b3f-4231-b92d-c1046d57b59c', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0111a-6b73-7f82-bc5e-6e025d20e6f9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7213, 'output_tokens': 126, 'total_tokens': 7339, 'input_token_details': {'cache_read': 7168}, 'output_token_details': {}}),
#               HumanMessage(content='I have some leftover paneer and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='45a825c9-7b64-4650-814f-37489f70ccc8'),
#               AIMessage(content='I already have some great results from my earlier search! Let me search for a couple more ideas to give you even more options.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 114, 'prompt_tokens': 7357, 'total_tokens': 7471, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 7296}, 'prompt_cache_hit_tokens': 7296, 'prompt_cache_miss_tokens': 61}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '4a269a27-290f-46a9-8289-75110ad02b02', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0111c-d19a-7840-9887-b46a21b854c9-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'paneer rice casserole recipe leftover'}, 'id': 'call_00_gVkfmfkUWzM5knEuuuxa4150', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'paneer bhurji with leftover rice recipe'}, 'id': 'call_01_DsuVsZRpUN5MzKiuQjlD2995', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 7357, 'output_tokens': 114, 'total_tokens': 7471, 'input_token_details': {'cache_read': 7296}, 'output_token_details': {}}),
#               ToolMessage(content='{"query": "paneer rice casserole recipe leftover", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://cookwithrenu.com/beetroot-paneer-rice-with-leftover-rice", "title": "Beetroot Paneer Rice With Leftover Rice (Easy Lunchbox ...", "content": "Make beetroot paneer rice using leftover rice in one pan, mildly spiced with peas, cashews, and lime, perfect for lunchboxes and meal prep.", "score": 0.7992077, "raw_content": null, "id": "da1542-00"}, {"url": "https://www.facebook.com/groups/foodiesplus/posts/952014385221569", "title": "Green paneer pulao recipe with leftover rice", "content": "This is a very quick recipe which you can make with leftover rice or fresh steamed rice. You need some greens and cottage cheese … vegetarian", "score": 0.7154444, "raw_content": null, "id": "9ceeee-01"}, {"url": "https://www.thebigsweettooth.com/baked-rice-casserole", "title": "Baked Rice Casserole", "content": "I once tried making a similar casserole using leftover chole, plain rice and added some vegetables and cheese. It was delicious and yours", "score": 0.60077465, "raw_content": null, "id": "a57a02-02"}, {"url": "https://www.indianhealthyrecipes.com/paneer-fried-rice", "title": "Paneer fried rice (Indian & Chinese 2 Ways) - Swasthi\'s Recipes", "content": "1 cup rice (or 2 to 2½ cups cooked rice)\\n 2 tablespoons oil (divided)\\n ¾ to 1 cup paneer (cold, cubed)\\n 2 to 3 tablespoons Thick curd (plain greek yogurt)\\n ½ teaspoon ginger garlic paste\\n ½ teaspoon red chilli powder\\n ¼ to ½ teaspoon garam masala\\n ⅛ teaspoon turmeric\\n ¼ teaspoon  salt (more to adjust)\\n ¼ to ½ cup spring onions (chopped, greens and whites separated)\\n ½ cup  carrot (chopped)\\n ¼ to ½ cup bell peppers\\n ¼ to ½ teaspoon black pepper (adjust to taste)\\n 2 cloves garlic chopped [...] 2. To a bowl, add\\n\\n 2 to 3 tbps of thick yogurt (greek yogurt or use strained yogurt)\\n ½ teaspoon ginger garlic paste\\n a large pinch of turmeric\\n ¼ teaspoon salt (adjust to taste)\\n ½ teaspoon red chilli powder\\n ¼ to ½ teaspoon garam masala. Mix all of the ingredients.\\n\\n3. Add ¾ to 1 cup cold paneer cubes. Mix well. and set aside for at least 15 mins\\n\\n4. Meanwhile chop and prepare [...] 1. Heat a pan with 1 tablespoon oil. Add the marinated paneer and fry on a high heat until all of the moisture dries up. Remove to a plate.\\n2. To the same pan, add more oil and hear. Add garlic, chillies and spring onion whites. Saute for 30 seconds.\\n3. Then add mixed vegetables and saute until the veggies are cooked yet remain crunchy.\\n4. Add fried paneer and spring onion greens. Pour soya sauce.", "score": 0.5568099, "raw_content": null, "id": "c91f3f-03"}, {"url": "https://theflavoursofkitchen.com/tawa-paneer-pulao-video-recipe", "title": "Paneer Tawa Pulao {Video Recipe}", "content": "Spicy flavourful Tawa Pulao with Paneer and vegetable is a delicious meal and it takes only 10 minutes to make.", "score": 0.13828741, "raw_content": null, "id": "1d7e66-04"}], "response_time": 1.53, "request_id": "f3b41ef0-3c54-4c8d-b201-65af4777ad2a"}', name='web_search', id='0dc576d9-fce7-441d-bb42-ff748ee66270', tool_call_id='call_00_gVkfmfkUWzM5knEuuuxa4150'),
#               ToolMessage(content='{"query": "paneer bhurji with leftover rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.instagram.com/reel/C737aXfxLFD?hl=en", "title": "Paneer Bhurji Fried Rice Recipe Ingredients (for 2 people): - 1 ...", "content": "Paneer Bhurji Fried Rice Recipe Ingredients (for 2 people): - 1 bowl of Leftover Bhurji - 1 cup Rice - 1/2 medium sized chopped onion", "score": 0.88799405, "raw_content": null, "id": "0ab08c-00"}, {"url": "https://www.instagram.com/reel/DbcrDC_NPtv", "title": "This Paneer Bhurji Pulao is one of those recipes you can ...", "content": "Flavourful paneer bhurji mixed with perfectly cooked rice * 250g low-fat paneer, diced * 1 cup cooked rice * 1 tsp cumin seeds", "score": 0.741169, "raw_content": null, "id": "c4e6a7-01"}, {"url": "https://www.indianhealthyrecipes.com/paneer-bhurji-recipe", "title": "Paneer Bhurji Recipe - Swasthi\'s Recipes", "content": "5. Mix and saute until the raw smell goes off from the mixture & the masala leaves the sides of the pan.\\n6. Stir in peas or capsicum if using. Fry until capsicum turns slightly soft. Crumble paneer well and add to the pan.\\n7. Stir and fry till everything blends well just for 2 minutes. Taste it and add more salt and spices if required.\\n8. Turn off the stove. Add 2 tbsp chopped coriander leaves. Serve paneer bhurji with roti, paratha or bread. Sprinkle some lemon juice before serving. [...] 1. Pour 4 cups milk to a pot and bring it to a boil. Add 1 tbsp vinegar or lemon juice and Stir. When the milk begins to curdle well, turn off the stove. If the milk does not curdle then add 1 tbsp more vinegar.\\n2. Drain it to a colander lined with a muslin cloth. Rinse it well under running water. Squeeze off the excess whey and make a knot with the cloth.\\n3. Hang the paneer for about 10 to 15 minutes to remove excess whey. Meanwhile chop the onions & tomatoes finely. [...] 1. To make Paneer Bhurji gravy cool the onion tomato masala after sautéing the onion, tomatoes and spices. Blend to a paste with little water. Heat 1 tsp oil and add a bay leaf, 2 cardamoms and half teaspoon cumin seeds. When they splutter, add the onion tomato paste and pour ½ to ¾ water. Cook until you see traces of oil on top then proceed with the next steps.", "score": 0.68723184, "raw_content": null, "id": "d20c66-02"}, {"url": "https://www.youtube.com/watch?v=bcMCYc12R5E", "title": "Quick Lunch Box Recipe/ Paneer Bhurji Rice/ Paneer Rice", "content": "Shredded paneer – 200 grams Cooked basmati rice – 200 grams Salt Coriander leaves", "score": 0.68420124, "raw_content": null, "id": "ce3d7c-03"}, {"url": "https://traditionallymodernfood.com/paneer-rice-paneer-bhurji-rice", "title": "Paneer bhurji rice", "content": "Ingredients: 1⁄2 tbsp ghee 1⁄4 tsp cumin seeds 2 tbsp finely chopped onion 1 tsp ginger-garlic paste 2 tbsp diced bell pepper 1 for a quick and", "score": 0.67037153, "raw_content": null, "id": "5374ae-04"}], "response_time": 1.75, "request_id": "32b01254-66b6-4b4c-b9db-a0b60d59e901"}', name='web_search', id='859b295d-0cb1-4f99-95c6-7c7c66bca2a7', tool_call_id='call_01_DsuVsZRpUN5MzKiuQjlD2995'),
#               AIMessage(content="I found even more great options for you! Here are the best recipes you can make with your leftover **paneer and rice**:\n\n---\n\n## 🍽️ Recipe Suggestions\n\n### 1. **Paneer Fried Rice** ⭐ *My top pick*\nThe classic and easiest option. Great for leftover rice!\n- **Indian style**: Sauté garlic, ginger, onions, and green chilies with veggies, add marinated paneer cubes, then toss in rice with spices.\n- **Chinese style**: Add soy sauce, vinegar, chili sauce, and black pepper for an Indo-Chinese kick.\n\n---\n\n### 2. **Paneer Bhurji Rice / Pulao**\nCrumble the paneer and sauté it with onion, tomato, ginger-garlic paste, and spices (turmeric, red chili, garam masala) to make a spiced **paneer bhurji (scrambled paneer)**, then mix it with your leftover rice. Quick, flavorful, and comforting!\n\n---\n\n### 3. **10-Minute Paneer Masala Pulao**\nSpecifically designed for leftover rice:\n- Heat oil + butter, add mustard seeds, cumin, curry leaves, and green chilies\n- Sauté paneer cubes with all the spices\n- Toss in leftover rice and cook for a few minutes\n- Perfect for a quick lunch or dinner!\n\n---\n\n### 4. **Paneer Pulao**\nA more elaborate one-pot dish with whole spices (bay leaf, cinnamon, cloves, cardamom), sautéed onions, veggies, mint, and coriander. Fold in fried paneer cubes at the end.\n\n---\n\n### 5. **Paneer Tikka Rice Bowl**\nMarinate paneer in yogurt and spices, grill or pan-fry until charred, and serve over rice with fresh salad, lemon, and a yogurt drizzle. Modern and healthy!\n\n---\n\n### 6. **Beetroot Paneer Rice**\nA colorful twist — sauté grated beetroot with spices and paneer, then toss with leftover rice. Mild, slightly sweet, and great for lunchboxes.\n\n---\n\n### 7. **Green Paneer Pulao**\nBlend fresh greens (spinach, mint, coriander) into a paste, use it to flavor your rice, and mix in paneer cubes. Fresh, healthy, and vibrant!\n\n---\n\n## 🌟 Which one sounds best to you?\nIf you want, I can give you the **detailed step-by-step recipe** for any of these. Just let me know which one you'd like to make, and also if there are any other ingredients you have on hand (onions, tomatoes, sauces, etc.) so I can tailor the recipe to your kitchen! 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 567, 'prompt_tokens': 9342, 'total_tokens': 9909, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 7424}, 'prompt_cache_hit_tokens': 7424, 'prompt_cache_miss_tokens': 1918}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'cb21e6b9-f407-4b9d-a407-954fe66eb0c8', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0111c-e20b-7753-8a65-1519f5eaa546-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9342, 'output_tokens': 567, 'total_tokens': 9909, 'input_token_details': {'cache_read': 7424}, 'output_token_details': {}})]}

# %%
follow_up_questions = HumanMessage(content="I liked the Paneer Fried Rice dish chinese style. so give me detailed step-by-step recipe.")

response = agent.invoke(
    {"message": [follow_up_questions]},
    config,
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover paneer and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='803db585-33f8-43db-8bfb-7e8411c06afe'),
#               AIMessage(content='Let me search for some delicious recipes you can make with paneer and rice as your main ingredients!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 107, 'prompt_tokens': 345, 'total_tokens': 452, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 345}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '2ca8285a-e3dc-45a6-8a83-47535d913cd6', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0110e-279f-7552-8ea4-90437554c082-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'easy recipes with leftover paneer and rice'}, 'id': 'call_00_SzBjCzQkp7KBqkI6aiPr2202', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'paneer rice recipes quick and easy'}, 'id': 'call_01_WUtmq9LHPOdM88VLjxX09455', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 345, 'output_tokens': 107, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}),
#               ToolMessage(content='{"query": "easy recipes with leftover paneer and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=IYJkWxwlmIE&vl=en-US", "title": "10-Minute Paneer Pulao Recipe | Leftover rice tiffin recipe | Easy paneer pulao dinner idea | Nirav", "content": "Transform your leftover rice into a mouthwatering Paneer Masala Pulao in just 10 minutes! This quick, flavorful recipe is perfect for tiffin boxes or a simple dinner. Spiced perfectly with tender paneer and aromatic herbs, it’s the perfect way to avoid food waste while enjoying a hearty, satisfying meal. Easy to make, delicious to eat!\\"\\n\\nSearchable Keywords: [...] बचे चावल से सिर्फ 10 मिनट में बनाए मजेदार और चटपटा पनीर मसाला राइस टिफिन के लिए परफेक्ट और रात के खाने में सबका दिल जीतने वाला और साथ में ठंडी दही मिल जाए ओए होय होए इसका स्वाद और भी लाजवाब हो जाता है सबसे पहले कढ़ाई में डालेंगे 2 टेबलस्पून तेल तेल को मध्यम आंच पे गरम करें फिर इसमें हम डालेंगे 30 ग्रा बटर जैसे ही बटर मेल्ट हो जाए डालेंगे 1 टीस्पून राई जैसे ही राई में से फूटने की आवाज आनी शुरू हो जाए डालेंगे 1 टीस्पून जीरा एक या दो मीडियम साइज की कटी हुई हरी मिर्च 12 से 15 कड़ी पत्ता दो छोटी [...] से टुकड़ों में काट ले फिर आधी छोटी चम्मच कश्मीरी लाल मिर्च पाउडर आधी छोटी चम्मच धनिया पाउडर धनिया जीरा पाउडर ना डाले आधी छोटी चम्मच हल्दी पाउडर एक टीस्पून पांव भाजी मसाला इसे जरूर से डालिए आधी छोटी चम्मच गरम मसाला अब यहां पे डाली हुई सभी चीजों को अच्छे से मिक्स कर ले और इस तरह से चलाते हुए दो से 3 मिनट तक पनीर को पका लें जब मसाले पनीर के साथ अच्छे से मिक्स हो जाए थोड़ा पनीर को भून लेने के बाद इसमें हम डालेंगे लेफ्ट ओवर राइस ये मैं चार कटोरी उबले हुए चावल डाल रहा हूं और और इसी के साथ डालेंगे नमक", "score": 0.890761, "raw_content": null, "id": "12dd62-00"}, {"url": "https://www.sharmispassions.com/paneer-pulao-recipe", "title": "Paneer Pulao Recipe | Paneer Rice Recipe - Sharmis Passions", "content": "Add ¼ cup carrot, ⅓ cup green peas along with ¼ cup mint, coriander leaves.\\n Saute well for 2 minutes.\\n Add drained basmati rice and give a quick mix.\\n Add 2 cups water. Check and adjust salt at this stage. The water should be salty only then when rice is cooked salt will be apt.\\n Pressure cook for 2 whistles in medium flame. Switch off.\\n Add fried paneer cubes.\\n Mix it well and your paneer pulao is ready to serve!\\n Serve it with plain curd or onion raita. [...] 12.Saute well for 2 minutes.\\n\\n13.Add drained basmati rice and give a quick mix.\\n\\n14.Add 2 cups water. Check and adjust salt at this stage. The water should be salty only then when rice is cooked salt will be apt.\\n\\n15.Pressure cook for 2 whistles in medium flame. Switch off.\\n\\n16.Add fried paneer cubes.\\n\\n17.Mix it well and your paneer pulao is ready to serve!\\n\\nServe it with plain curd or onion raita.\\n\\n## Expert Tips [...] First rinse 1 cup basmati rice in water well at least 2-3 times then soak it in water for 30 minutes.\\n After 30 minutes drain water and set the rice aside.\\n To a bowl add 200 grams paneer along with salt to taste, ½ teaspoon red chili powder and ¼ teaspoon garam masala powder, ½ teaspoon ginger garlic paste.\\n Mix it well until the spices coat well.\\n Meanwhile to a pan add little oil and shallow fry the paneer cubes in batches.", "score": 0.76554126, "raw_content": null, "id": "f9a7ba-01"}, {"url": "https://hebbarskitchen.com/paneer-fried-rice-recipe-paneer-fry-rice", "title": "paneer fried rice recipe | paneer fry rice | veg paneer fried rice", "content": "Anyway, I would like to conclude this post with some tips, suggestions, and variations for a perfect paneer fried rice recipe. Firstly, I would heavily recommend using dry or leftover basmati rice for this recipe. If you plan to use freshly cooked rice, ensure to make it moisture-free by drying it out on a plate. Secondly, with respect to the addition of vegetables, it is completely open-ended. I have added the basic vegetables, but you can easily experime ...
#               ToolMessage(content='{"query": "paneer rice recipes quick and easy", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.sharmispassions.com/paneer-pulao-recipe", "title": "Paneer Pulao Recipe | Paneer Rice Recipe - Sharmis Passions", "content": "12.Saute well for 2 minutes.\\n\\n13.Add drained basmati rice and give a quick mix.\\n\\n14.Add 2 cups water. Check and adjust salt at this stage. The water should be salty only then when rice is cooked salt will be apt.\\n\\n15.Pressure cook for 2 whistles in medium flame. Switch off.\\n\\n16.Add fried paneer cubes.\\n\\n17.Mix it well and your paneer pulao is ready to serve!\\n\\nServe it with plain curd or onion raita.\\n\\n## Expert Tips [...] Add ¼ cup carrot, ⅓ cup green peas along with ¼ cup mint, coriander leaves.\\n Saute well for 2 minutes.\\n Add drained basmati rice and give a quick mix.\\n Add 2 cups water. Check and adjust salt at this stage. The water should be salty only then when rice is cooked salt will be apt.\\n Pressure cook for 2 whistles in medium flame. Switch off.\\n Add fried paneer cubes.\\n Mix it well and your paneer pulao is ready to serve!\\n Serve it with plain curd or onion raita. [...] 3.To a bowl add 200 grams paneer along with salt to taste, ½ teaspoon red chili powder and ¼ teaspoon garam masala powder, ½ teaspoon ginger garlic paste.\\n\\n4.Mix it well until the spices coat well.\\n\\n5.Meanwhile to a pan add little oil and shallow fry the paneer cubes in batches.\\n\\n6.Fry until golden brown. Fry in batches repeat to finish. Remove the paneer cubes and set it aside.", "score": 0.8865877, "raw_content": null, "id": "18b9dc-00"}, {"url": "https://www.indianhealthyrecipes.com/paneer-pulao", "title": "Paneer Pulao Recipe | Paneer Rice - Swasthi\'s Recipes", "content": "3. Saute ginger garlic paste till the raw smell is gone, for 1 minute. Add all the chopped veggies, mint and coriander leaves. Saute for 2 to 3 mins. Pour water and stir in salt. Taste test and adjust salt to make it slightly salty.\\n4. Bring it to a boil. Add soaked and drained rice and pressure cook for 1 whistle on a medium flame. If cooking in a pot, cover and cook on a low flame until the rice is done. [...] 1. Prep-up paneer: Add all the marination ingredients including 1½ tablespoon oil to paneer. Mix and set aside. If it is too dry, sprinkle 1 tbsp water. Rinse and soak rice in water for 15 mins.\\n2. Make pulao rice: Heat oil or ghee in a pot or cooker. Add all the whole spices. When they begin to sizzle, add sliced onions & green chilies. Saute them until golden. [...] More Rice Recipes you may like  \\nTawa pulao  \\nJeera rice  \\nMatar pulao  \\nCarrot pulao\\n\\nIf you love paneer, you may check more Paneer Recipes here.\\n\\nPhoto Guide\\n\\n## Step by Step Photo Instructions\\n\\n1. Rinse 1½ cups aged basmati rice thrice and optionally soak it in water for 15 mins. Meanwhile prep up the rest. Rinse 1½ cups cubed paneer to make it moist or sprinkle 1 tbsp of water. Drain the water completely. Add", "score": 0.85825616, "raw_content": null, "id": "eb8a9d-01"}, {"url": "https://www.indianhealthyrecipes.com/paneer-fried-rice", "title": "Paneer fried rice (Indian & Chinese 2 Ways) - Swasthi\'s Recipes", "content": "1. Heat a pan with 1 tablespoon oil. Add the marinated paneer and fry on a high heat until all of the moisture dries up. Remove to a plate.\\n2. To the same pan, add more oil and hear. Add garlic, chillies and spring onion whites. Saute for 30 seconds.\\n3. Then add mixed vegetables and saute until the veggies are cooked yet remain crunchy.\\n4. Add fried paneer and spring onion greens. Pour soya sauce. [...] 1. Add 1 tbsp olive oil to a pan and fry 2 chopped garlic cloved and 1 strand of mace. Mace imparts a good aroma to the rice and so you can skip using sauce for this recipe.\\n\\n2. Add 3/4 cup chopped veggies and fry until slightly tender yet crunchy. I used carrots, beans , spring onions and capsicums. ...
#               AIMessage(content='Let me search for a couple more specific recipe ideas to give you a good variety of options.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 107, 'prompt_tokens': 4883, 'total_tokens': 4990, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 256}, 'prompt_cache_hit_tokens': 256, 'prompt_cache_miss_tokens': 4627}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '18ce6f71-98dd-4d72-b676-bab3f82a18c7', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0110e-3412-7e81-9794-7d216bc10909-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'paneer khichdi recipe leftover rice'}, 'id': 'call_00_8UNxGaXTOYDSDgT5BPcY5678', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'paneer tikka rice bowl recipe easy'}, 'id': 'call_01_3mtKcbSQThxrlSHFbVTY0530', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 4883, 'output_tokens': 107, 'total_tokens': 4990, 'input_token_details': {'cache_read': 256}, 'output_token_details': {}}),
#               ToolMessage(content='{"query": "paneer khichdi recipe leftover rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/chefatlarge/posts/5546236995464897", "title": "Dal khichdi, a flavorful leftover rice and dal makeover - Facebook", "content": "Ingredients : 1 cup leftover MoongDal Khichdi 1/4 cup corn boiled and chrushed 3 tbsp corn Flour 1/4 cup paneer grated 1 potato boiled and", "score": 0.826278, "raw_content": null, "id": "df8d24-00"}, {"url": "https://www.facebook.com/yourfoodlab/posts/if-you-also-have-leftover-rice-at-your-home-i-have-an-amazing-recipe-for-you-the/1472379620906309", "title": "If you also have leftover rice at your home, I have an amazing recipe for ...", "content": "3) PANEER FRIED RICE Ingredients: • 2 cups cooked basmati rice • 200 g paneer cubes • 2 tbsp oil • ½ cup chopped onion • ½ cup chopped capsicum/", "score": 0.798643, "raw_content": null, "id": "2ecbce-01"}, {"url": "https://staging.foodfood.com/public/recipedetails/egg-paneer-khichdi", "title": "Egg & Paneer Khichdi - Food Food", "content": "Key Ingredients: Eggs · Cottage cheese (paneer) · Leftover rice · Leftover dal. Leftover rice and dal put to good use – very", "score": 0.75831425, "raw_content": null, "id": "357289-02"}, {"url": "https://www.instagram.com/reel/CveSBt2qZx8?hl=en", "title": "Dal chawal pancake - you can use this recipe for leftover Khichdi, dalia ...", "content": "INGREDIENTS: 1 cup leftover rice 1/2 cup leftover moong dal 1 cup finely chopped cabbage 1/2 cup finely chopped", "score": 0.75181264, "raw_content": null, "id": "8d90ac-03"}, {"url": "https://www.reddit.com/r/Cheap_Meals/comments/brhw2t/dal_khichdi_recipe_with_paneer_an_indian_rice_dish", "title": "Dal Khichdi Recipe with Paneer (an Indian rice dish) - Reddit", "content": "Khichdi + paneer? I saw such combination first time. It looks tasty though, do you make this variation on your own or dish like this", "score": 0.43597415, "raw_content": null, "id": "b0a7a9-04"}], "response_time": 2.12, "request_id": "0e924b31-9f87-4c2c-a52a-5c777f71358e"}', name='web_search', id='657a515c-c5c5-46d7-9f8b-13d6a95685af', tool_call_id='call_00_8UNxGaXTOYDSDgT5BPcY5678'),
#               ToolMessage(content='{"query": "paneer tikka rice bowl recipe easy", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.honeywhatscooking.com/paneer-tikka-rice-bowl", "title": "Paneer Tikka Rice Bowl (Air Fryer version)", "content": "To Assemble Paneer Tikka Rice Bowl (makes 4 servings) · Add rice to a bowl · Add crisp lettuce, chopped · Add cucumber salad · Add paneer & veggies", "score": 0.8173562, "raw_content": null, "id": "4d26a1-00"}, {"url": "https://www.dillandthyme.com/paneer-tikka-masala-rice", "title": "Paneer Tikka Masala Rice | Dill and Thyme", "content": "For the rice: While this mixture is cooling down, place the same pan on the stove and add a couple of tablespoons of ghee/ oil. Add the sliced onions and let cook for 5 minutes. Add the ginger-garlic paste and cook for another 5 minutes. Now add sliced red bell peppers, paneer, salt and mix well.Cook until the peppers have softened. [...] Raita is typically served with most Indian style rice dishes or anything spicy since the yoghurt in the raita balances the heat in the food. Just add some yoghurt to a bowl. Thin it down by adding water to reach the desired consistency. Add salt, cumin powder and some chili powder(optional). You can also add chopped tomatoes, cucumber and/or onions to this. Topping with chopped cilantro leaves is optional. [...] Heat the kadai or braiser and add some ghee. Once hot, add the onions and let this cook for a few minutes. Add the ginger-garlic paste, mix and again cook for 5-7 minutes.\\n Now add the chopped tomatoes, tomato paste and saute for a minute or so. Add all the powdered spices and the kasuri methi. Season with salt and add a cup of boiling water.", "score": 0.7668008, "raw_content": null, "id": "47a750-01"}, {"url": "https://www.instagram.com/p/DXBZsS-EwkL?__d=", "title": "My fav lunch meal = Paneer Tikka Rice Bowl 🍢 ...", "content": "Quick and tasty Paneer Rice Bowl recipe Perfect high-protein meal for lunch or dinner. Easy to make, healthy, and super delicious!", "score": 0.72019166, "raw_content": null, "id": "48c7ad-02"}], "response_time": 1.94, "request_id": "b3787434-03f9-41cd-b14b-ecf076fe12b4"}', name='web_search', id='8b2ee61d-df3a-43c1-8f4e-699106644849', tool_call_id='call_01_3mtKcbSQThxrlSHFbVTY0530'),
#               AIMessage(content="Great! I found some fantastic recipe options for you. Here are the best recipes you can make with your leftover paneer and rice:\n\n---\n\n## 🍽️ Recipe Suggestions for Paneer + Rice\n\n### 1. **Paneer Fried Rice** (Indian-Chinese style)\nThis is probably the most popular and versatile option for leftover rice. There are two ways you can make this:\n- **Indian style**: Sauté garlic, ginger, green chilies, and onions with veggies, add crumbled/cubed paneer, then toss in your leftover rice with spices.\n- **Chinese style**: Add soy sauce, chili sauce, vinegar, and black pepper for a spicy Indo-Chinese twist.\n\n**Key ingredients you'll likely need:** oil, garlic, ginger, onion, green chilies, soy sauce (for Chinese version), black pepper, salt, and whatever veggies you have on hand (carrots, capsicum, beans, spring onions).\n\n---\n\n### 2. **Paneer Pulao**\nA one-pot aromatic rice dish. Marinate paneer cubes with yogurt, red chili powder, garam masala, and ginger-garlic paste, then shallow fry them. Cook rice with whole spices (cumin, bay leaf, cinnamon, cloves), sautéed onions, veggies, and fresh herbs (mint and coriander). Fold the fried paneer into the cooked rice.\n\n**Best served with:** plain yogurt/raita.\n\n---\n\n### 3. **Paneer Tikka Rice Bowl**\nA modern, healthy take — marinate paneer cubes with yogurt, spices, and grill or air-fry them until charred. Serve over your leftover rice with fresh salad (lettuce, cucumber, onion), and optionally a drizzle of lemon and yogurt-based sauce.\n\n---\n\n### 4. **Paneer Masala Pulao (10-minute version)**\nA super quick option specifically designed for **leftover rice**! In a pan:\n- Heat oil + butter, add mustard seeds and cumin\n- Add green chilies, curry leaves, ginger-garlic paste\n- Sauté paneer cubes with red chili powder, coriander powder, turmeric, garam masala\n- Toss in your leftover rice, mix well, and cook for 2-3 minutes\n\n---\n\n### 5. **Paneer Khichdi Cakes/Tikkis** (Creative option!)\nIf you also have some dal or moong lentils, you can mix leftover rice with mashed dal, grated paneer, and spices, then shallow fry them into crispy patties/tikkis.\n\n---\n\n## 🌟 My Top Recommendation:\n**Paneer Fried Rice** — it's the easiest, fastest, and makes the best use of leftover rice and paneer. Perfect for a weekday lunch or dinner!\n\n---\n\nWould you like me to give you the **detailed step-by-step recipe** for any of these? Just let me know which one sounds best to you! 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 602, 'prompt_tokens': 6312, 'total_tokens': 6914, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 4864}, 'prompt_cache_hit_tokens': 4864, 'prompt_cache_miss_tokens': 1448}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '8472cc04-3d7e-4ecf-a6e7-be5952c20429', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0110e-4630-7983-b743-18d762c0a7c5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6312, 'output_tokens': 602, 'total_tokens': 6914, 'input_token_details': {'cache_read': 4864}, 'output_token_details': {}}),
#               AIMessage(content="I found some great options! Let me know which recipe you'd like the detailed step-by-step instructions for, and I'll walk you through it. \n\nTo recap, here are your best options:\n1. **Paneer Fried Rice** (fastest & easiest, great for leftover rice)\n2. **Paneer Pulao** (one-pot aromatic, more elaborate)\n3. **Paneer Tikka Rice Bowl** (healthy modern twist)\n4. **10-Minute Paneer Masala Pulao** (specifically designed for leftover rice)\n5. **Paneer Khichdi Cakes** (crispy pan-fried patties, if you have dal)\n\nWhich one would you like the full recipe for? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 153, 'prompt_tokens': 6917, 'total_tokens': 7070, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 6912}, 'prompt_cache_hit_tokens': 6912, 'prompt_cache_miss_tokens': 5}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'abb31a9f-6953-4531-bb7d-edf930c537a0', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01116-3947-7a93-aaa9-8c8b2b701118-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6917, 'output_tokens': 153, 'total_tokens': 7070, 'input_token_details': {'cache_read': 6912}, 'output_token_details': {}}),
#               AIMessage(content="I found some great options! Let me know which one you'd like the full recipe for. To summarize:\n\n1. **Paneer Fried Rice** — Fastest and easiest, perfect for leftover rice\n2. **Paneer Pulao** — Aromatic one-pot dish\n3. **Paneer Tikka Rice Bowl** — Healthy modern twist\n4. **10-Minute Paneer Masala Pulao** — Made specifically for leftover rice\n5. **Paneer Khichdi Cakes** — Crispy pan-fried patties (if you also have some dal)\n\nWhich one would you like the detailed step-by-step recipe for? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 137, 'prompt_tokens': 7073, 'total_tokens': 7210, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 7040}, 'prompt_cache_hit_tokens': 7040, 'prompt_cache_miss_tokens': 33}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'd5060705-2910-4f51-99b5-39d51a262817', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0111a-31fe-7fe0-bdf4-a9c8b9535070-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7073, 'output_tokens': 137, 'total_tokens': 7210, 'input_token_details': {'cache_read': 7040}, 'output_token_details': {}}),
#               AIMessage(content="I found some great options! Let me know which one you'd like the full recipe for. To summarize:\n\n1. **Paneer Fried Rice** — Fastest and easiest, perfect for leftover rice\n2. **Paneer Pulao** — Aromatic one-pot dish\n3. **Paneer Tikka Rice Bowl** — Healthy modern twist\n4. **10-Minute Paneer Masala Pulao** — Made specifically for leftover rice\n5. **Paneer Khichdi** — Comforting one-pot meal\n\nWhich one would you like the detailed step-by-step recipe for? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 126, 'prompt_tokens': 7213, 'total_tokens': 7339, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 7168}, 'prompt_cache_hit_tokens': 7168, 'prompt_cache_miss_tokens': 45}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'cbd8dc4d-2b3f-4231-b92d-c1046d57b59c', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0111a-6b73-7f82-bc5e-6e025d20e6f9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7213, 'output_tokens': 126, 'total_tokens': 7339, 'input_token_details': {'cache_read': 7168}, 'output_token_details': {}})]}
